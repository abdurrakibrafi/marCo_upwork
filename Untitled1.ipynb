# %%
import requests

url = 'https://apiv2.api-cricket.com/cricket/'
params = {
    'method': 'get_livescore',
    'APIkey': 'd0ce723d890545175448b24c338321ca85e3bddaa3e2daea1eef6f3e62f2c246',
}

r = requests.get(url, params=params)
data = r.json()

# look at ONE match raw
print(data['result'][0])
# Out:
# {'event_key': '20950', 'event_date_start': '2026-03-30', 'event_date_stop': '2026-03-30', 'event_time': '10:00', 'event_home_team': 'Mid West Rhinos', 'home_team_key': '155', 'event_away_team': 'Mountaineers', 'away_team_key': '152', 'event_service_home': '', 'event_service_away': '', 'event_home_final_result': '84/1', 'event_away_final_result': '', 'event_home_rr': '3.04', 'event_away_rr': None, 'event_status': 'Lunch', 'event_status_info': 'Day 1 - Rhinos chose to bat.', 'league_name': 'Logan Cup', 'league_key': '8247', 'league_round': '', 'league_season': '2025-26', 'event_live': '1', 'event_type': 'TEST', 'event_toss': 'Mid West Rhinos, elected to bat first', 'event_man_of_match': '', 'event_stadium': 'Bulawayo Athletic Club', 'event_home_team_logo': 'https://apiv2.api-cricket.com/logo/155_mid-west-rhinos.png', 'event_away_team_logo': 'https://apiv2.api-cricket.com/logo/152_mountaineers.png', 'scorecard': {'Mid West Rhinos 1 INN': [{'innings': 'Mid West Rhinos 1 INN', 'player': '
# ...
